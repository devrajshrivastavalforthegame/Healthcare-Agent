# %%
import requests

OLLAMA_URL = "https://stowing-unspoiled-singer.ngrok-free.dev"
url = f"{OLLAMA_URL}/api/embeddings"

data = {
    "model": "nomic-embed-text",
    "prompt": "What is artificial intelligence?"
}

response = requests.post(url, json=data)

embedding = response.json()["embedding"]

print(len(embedding))
print(embedding[:5])
# Out:
# AI stands for Artificial Intelligence. It's like a super smart computer program that can think, learn, and make decisions on its own, just like humans do!
#
# Here are some simple examples to help you understand AI:
#
# 1. **Self-Driving Cars**: Imagine you're driving to work, but your car is actually driving itself! That's because the car has an AI system that can see, learn from experience, and adjust its route in real-time.
# 2. **Virtual Assistants**: You know Siri, Alexa, or Google Assistant? Those are AI-powered virtual assistants that listen to you, understand what you say, and respond accordingly.
# 3. **Image Recognition**: When you take a photo of a cat, an AI system can look at it and instantly identify the animal as a "cat"! It's like having a superpowerful detective in your phone.
# 4. **Chatbots**: Have you ever chatted with a robot online? That's an AI-powered chatbot that can have a conversation with you, answer questions, and even make jokes!
# 5. **Predictive Analytics**: Imagine predicting exactly when it will rain tomorrow or which movie will be the most popular next week! AI systems use data to make predictions like these.
# 6. **Natural Language Processing (NLP)**: AI can understand human language, just like you do! It can read, write, and speak in many languages.
#
# In simple terms, AI is a computer program that can:
#
# * Learn from experiences
# * Make decisions based on data
# * Recognize patterns
# * Understand human language
# * Act independently
#
# AI has the potential to transform many areas of our lives, making things more efficient, convenient, and fun!

# %%
from langchain_ollama import OllamaEmbeddings

# %%
embedding=(
    OllamaEmbeddings(model="llama3")
)

# %%
r1=embedding.embed_documents(
    [
        "hello i am devraj shrivastava"
        "hey i am  tanishq gehlot"
    ]
)
print(r1)
# Out:
# [[-0.023128094, 0.009726301, 0.028154401, -0.010044452, 0.010282167, 0.011737439, -0.026484534, -0.030811535, -0.036965564, 0.0010640993, 0.0077707223, -0.007944375, -0.0016309986, -0.009228426, -0.0018680491, 0.021747341, -0.0032478934, 0.02239616, -0.010701035, 0.00025266482, -0.011941013, -0.0046381885, 0.0052600084, 0.017383102, -0.016702086, 0.0024429113, 0.017654205, 0.038955804, 0.017747793, 0.013931417, 0.00235412, 0.022318434, 0.0013402223, -0.0062598386, -0.026708249, -0.018181253, 0.00672476, -0.014715155, -0.006615709, 0.008704647, 0.0023908329, -0.0045090746, 0.010680982, -0.019950228, -0.0056066955, 0.01530264, -0.0024652507, 0.014780353, 0.002936341, -0.020369204, 0.016929943, -0.0030988688, -0.00034065428, -0.007475946, 0.008672075, 0.0026681016, -0.004701527, -0.02585991, -0.017607203, -0.00050995813, -0.005079696, -0.017789051, -0.015676426, -0.006262548, -0.0010858156, 0.015755568, -0.0069372146, -0.015191901, 0.021208841, -0.00010311154, 0.00820577, 0.0027521315, 0.011189184, 0.020235598, -0.0015270229, 0.00717768, 0.0060844766, 0.012314927, 0.006466881, 0.0072735036, -0.02223577, -0.014025805, 0.0050402842, 0.016392788, 0.0058384975, 0.007335194, 0.0062842076, 0.005848736, -0.005883801, 0.006463446, 0.019864945, -0.0053466484, 0.007000961, -0.0018785372, 0.015776189, 0.0078007053, -0.019668525, 0.019502208, -0.012168451, -0.012966303, -0.00064944, -0.0041231276, -0.005337903, 0.008855481, 0.0043035033, -0.016659126, -1.3742766e-06, 0.028765269, 0.0005503221, -0.019637467, -0.003988704, 0.01304808, -0.0039822077, -0.005105624, 0.022018062, 0.014533817, -0.013705513, -0.0009566175, -0.0021079455, 0.012673051, 0.012099308, 0.023433032, 0.015173982, 0.0099177435, -0.006502261, -0.00013038365, 0.007024549, -0.0015347251, 0.026895896, 0.01672401, 0.007903423, -0.008016501, -0.016814282, 0.024886215, 0.0027553316, -0.008850686, -0.014365137, 0.0121526, -0.01399605, -0.0057859425, -0.0060850633, 0.0072409417, 0.021528598, 0.007119268, -0.002785022, 0.0005744073, 0.011206392, -0.018256068, 0.007458587, -0.008548819, -0.015379137, 0.0033813464, 9.8359465e-05, -0.0023862973, -0.0039895466, 0.005146014, -0.02186233, -0.016634433, 0.01500879, -0.007768976, -0.004696315, -0.0005566485, 0.0017864935, 0.02765463, -0.029080864, -0.011293802, 0.007896458, 0.003358847, -0.004686243, -0.0030946615, 0.011574457, 0.0011627631, 0.019951535, -0.012482383, -0.005645779, -0.002241853, 0.00082023686, -0.009802513, 0.005933311, 0.019696154, -0.0054203477, -0.0005861156, 0.0030832766, 0.0084613925, 0.027202794, 0.004019251, 0.0079894895, 0.003975321, 0.01566808, -0.012695699, 0.021972504, 0.00011906391, -0.017130716, 0.0075103953, 0.0029385502, 0.004177875, 0.0039911573, 0.016506303, -0.0063642277, -0.012982939, -0.013505663, -0.006242799, 0.011320495, -0.037232716, -0.012339869, -0.001236522, 0.0061850883, -0.0014668495, -0.00696411, 0.013454374, 0.0013989506, -0.003363791, -0.008651288, -0.015365038, -0.013529131, 0.018184835, -0.0032305417, 0.021691695, 0.004829165, -0.006187014, 0.009564958, 0.0011358189, 0.007667204, 0.0027709508, -0.004435116, 0.0049538435, -0.0031323005, -0.01668166, 0.014699041, 0.027128123, 0.02129651, -0.002900849, -0.0066114473, -0.0014921976, -0.008466302, 0.008687295, 0.0069045727, 0.022404455, 0.0046549537, 0.0031020008, 0.01898199, -0.0038341288, -0.008371496, 0.015035633, 0.004250368, 0.0010147697, -0.009518844, -0.002210071, -0.0037059404, -0.0030699756, -0.012379296, 0.0015924631, 0.0019065429, -0.0065177986, 0.003764119, 0.0056864256, 0.004020087, -0.009958774, -0.015070988, 0.0062715188, -0.006892281, -0.0071177175, -0.019716538, -0.016084354, -0.01911941, -0.004734385, -0.010563276, -0.011016385, 0.02009585, -0.023328736, -0.011895236, -0.004846269, -0.0053162132, -0.02149013, 0.0008294919, 0.0130252605, -0.0026038003, -0.005733398, 0.0047405697, 0.0049178354, -0.017558137, -0.002604679, -0.0014780182, 0.020835657, 0.010860928, 0.010491181, 0.002600762, 0.0020932131, 0.02438004, -0.050159812, -0.1 ...

# %%
docs
# Out:
# [Document(metadata={'source': 'data.txt'}, page_content='hello tanishq gehlot this sidesjgdjasfjasgjfgasfas]hasfjasgfgadskf\n\\asfbadsfdjkfbds\nsdfdsfds\nfsd\nsdfdsfdsf\ndsf\ndsfdsf\ndsffds\nds\nfsddsf\ndsfdsfdsf\ndsfdsfdsfdsf')]

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Load CSV
loader = CSVLoader(file_path="healthcare_dataset.csv")

documents = loader.load()

# Split documents
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=20
)

docs = text_splitter.split_documents(documents)

# Embeddings
embeddings = OllamaEmbeddings(
    model="nomic-embed-text"
)

# Create FAISS DB
db = FAISS.from_documents(docs, embeddings)

# SAVE DATABASE
db.save_local("faiss_index")

print("FAISS Database Saved Successfully!")
# Out:
# Patient_ID: P0038
# Age: 19
# Gender: Female
# Weight: 71.1
# Height: 194.3
# Symptoms: Anxiety
# Symptom_Duration: 2 days
# Severity_Level: Moderate
# Existing_Conditions: Food Poisoning
# Allergies: worry
# Current_Medications: no
# Suggested_Specialist: General Physician
# Possible_Condition: Diabetes
