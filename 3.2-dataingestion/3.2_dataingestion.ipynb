# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader('html.pdf')
docs =loader.load()
docs
# Out:
# incorrect startxref pointer(1)
# parsing for Object Streams
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# ...

# %%
from langchain.text_splitters import recurs
speech=""
with open("data.txt") as f:
    speech=f.read()

    text_splitter=Recuesivecharactertextsplitter(chunk_size=100,chunk_overlap=20)
    text=text_splitter.create_document([speech])
    print(text[0])
    print(text[1])
    print(text[2])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain.text_splitters import recurs
#       2 speech=""
#       3 with open("data.txt") as f:
#       4     speech=f.read()
#
# ModuleNotFoundError: No module named 'langchain.text_splitters'

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from langchain_ollama import ollamaEmbeddings
#       2
#       3 embeddings-ollamaEmbeddings (model="text-embedding-3-large")
#       4
#
# ImportError: cannot import name 'ollamaEmbeddings' from 'langchain_ollama' (c:\Users\darshan\OneDrive\Desktop\code's\hcl projet\env3\Lib\site-packages\langchain_ollama\__init__.py)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 r1 = embeddings.embed_documents(
#       2 ["Alpha is the first letter of Greek alphabet",
#       3 "Beta is the second letter of Greek alphabet",]
#       4 )
#
# NameError: name 'embeddings' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 embeddings=(
# ----> 2 ollamaEmbeddings(model="gamma:2b")
#       3 )
#
# NameError: name 'ollamaEmbeddings' is not defined

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [optparse.groups]Usage:[/]
#   c:\Users\darshan\OneDrive\Desktop\code's\hcl projet\env3\Scripts\python.exe -m pip install \[options] <requirement specifier> \[package-index-options] ...
#   c:\Users\darshan\OneDrive\Desktop\code's\hcl projet\env3\Scripts\python.exe -m pip install \[options] -r <requirements file> \[package-index-options] ...
#   c:\Users\darshan\OneDrive\Desktop\code's\hcl projet\env3\Scripts\python.exe -m pip install \[options] [-e] <vcs project url> ...
#   c:\Users\darshan\OneDrive\Desktop\code's\hcl projet\env3\Scripts\python.exe -m pip install \[options] [-e] <local project path> ...
#   c:\Users\darshan\OneDrive\Desktop\code's\hcl projet\env3\Scripts\python.exe -m pip install \[options] <archive url/path> ...
#
# no such option: -u
